# %% [markdown]
# # **Facial Feature Detection**
# * **Face Landmark Estimation**: Finding the locaton of the key points on a face. Example: Tip of the nose, center of each eye.
# The same Face Landmark Estimation should work for any face.
# ![image.png](attachment:image.png)
# * **Face Alignment**: Adjusting an original face image so that key facial features line up with apredefined template.

# %%
#!pip install dlib
# !pip install face_recognition
#!pip install pillow
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import PIL.Image
import PIL.ImageDraw
import face_recognition

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# Collecting face_recognition
#   Downloading face_recognition-1.3.0-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: dlib>=19.7 in /opt/conda/lib/python3.7/site-packages (from face_recognition) (19.20.0)
# Requirement already satisfied: Pillow in /opt/conda/lib/python3.7/site-packages (from face_recognition) (5.4.1)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.7/site-packages (from face_recognition) (1.18.1)
# Collecting face-recognition-models>=0.3.0
#   Downloading face_recognition_models-0.3.0.tar.gz (100.1 MB)
#      |████████████████████████████████| 100.1 MB 24 kB/s
# Requirement already satisfied: Click>=6.0 in /opt/conda/lib/python3.7/site-packages (from face_recognition) (7.1.1)
# Building wheels for collected packages: face-recognition-models
# done
#   Created wheel for face-recognition-models: filename=face_recognition_models-0.3.0-py2.py3-none-any.whl size=100566172 sha256=b2c0c6210f02d63c035a0ecae002e67cff5a5d9775f2dbe268397644988c2e3c
#   Stored in directory: /root/.cache/pip/wheels/d6/81/3c/884bcd5e1c120ff548d57c2ecc9ebf3281c9a6f7c0e7e7947a
# Successfully built face-recognition-models
# Installing collected packages: face-recognition-models, face-recognition
# Successfully installed face-recognition-1.3.0 face-recognition-models-0.3.0
# /kaggle/input/input-people2/rihanna.jpg
# /kaggle/input/input-people2/ariana.jpg
# /kaggle/input/input-people2/input_people/miranda1.jpg
# /kaggle/input/input-people2/input_people/adriana.jpg
# /kaggle/input/input-people/friends.jpg
# /kaggle/input/input-people/jennifer-aniston-as-rachel.jpg

# %%
#data loading
image=face_recognition.load_image_file("../input/input-people/friends.jpg")
face_landmarks_list=face_recognition.face_landmarks(image)
num_of_faces=len(face_landmarks_list)
print("{} face(s) found in this image".format(num_of_faces))

pil_image=PIL.Image.fromarray(image)
draw=PIL.ImageDraw.Draw(pil_image)

for face_landmarks in face_landmarks_list:
    
    for name,list_of_points in face_landmarks.items():
        #location of the each facial feature
        print("The {} in this face has the following points: {}".format(name,list_of_points))
        
        draw.line(list_of_points, fill="blue", width=3)
        
pil_image.show()
plt.imshow(pil_image)
plt.show()
# Out:
# 6 face(s) found in this image
# The chin in this face has the following points: [(438, 45), (432, 57), (427, 70), (423, 84), (423, 97), (426, 109), (433, 119), (439, 129), (449, 136), (462, 140), (477, 139), (492, 138), (505, 133), (514, 125), (521, 114), (527, 103), (532, 91)]
# The left_eyebrow in this face has the following points: [(451, 37), (460, 36), (468, 40), (474, 44), (479, 50)]
# The right_eyebrow in this face has the following points: [(495, 57), (505, 59), (513, 63), (520, 68), (524, 75)]
# The nose_bridge in this face has the following points: [(482, 62), (477, 69), (473, 75), (468, 82)]
# The nose_tip in this face has the following points: [(460, 84), (463, 88), (466, 91), (471, 92), (476, 93)]
# The left_eye in this face has the following points: [(455, 50), (462, 50), (468, 53), (471, 59), (465, 57), (460, 54)]
# The right_eye in this face has the following points: [(494, 70), (501, 70), (507, 74), (511, 79), (505, 77), (499, 74)]
# The top_lip in this face has the following points: [(447, 94), (453, 94), (459, 95), (463, 99), (469, 100), (476, 105), (483, 111), (480, 110), (467, 104), (461, 102), (458, 99), (449, 96)]
# The bottom_lip in this face has the following points: [(483, 111), (472, 113), (463, 112), (457, 110), (453, 107), (449, 102), (447, 94), (449, 96), (456, 101), (460, 104), (466, 106), (480, 110)]
# The chin in this face has the following points: [(121, 344), (121, 357), (123, 370), (126, 383), (132, 395), (141, 404), (151, 412), (163, 419), (175, 419), (186, 416), (196, 409), (204, 401), (211, 391), (216, 380), (218, 368), (218, 356), (218, 344)]
# The left_eyebrow in this face has the following points: [(131, 330), (139, 326), (147, 325), (156, 327), (164, 331)]
# The right_eyebrow in this face has the following points: [(186, 330), (194, 327), (202, 326), (210, 327), (215, 331)]
# The nose_bridge in this face has the following points: [(176, 340), (176, 349), (177, 359), (177, 369)]
# The nose_tip in this face has the following points: [(166, 373), (171, 375), (176, 377), (181, 375), (185, 373)]
# The left_eye in this face has the following points: [(141, 340), (147, 336), (154, 336), (160, 342), (153, 343), (146, 342)]
# The right_eye in this face has the following points: [(187, 342), (193, 336), (200, 336), (205, 341), (201, 343), (194, 343)]
# The top_lip in this face has the following points: [(149, 384), (160, 384), (170, 384), (176, 385), (182, 384), (189, 384), (196, 385), (193, 387), (182, 386), (175, 387), (169, 387), (153, 386)]
# The bottom_lip in this face has the following points: [(196, 385), (189, 392), (181, 396), (175, 396), (169, 396), (159, 393), (149, 384), (153, 386), (169, 390), (175, 391), (181, 390), (193, 387)]
# The chin in this face has the following points: [(699, 343), (698, 359), (699, 374), (700, 389), (703, 403), (712, 416), (722, 427), (732, 438), (745, 442), (759, 441), (772, 432), (783, 422), (793, 411), (799, 397), (803, 384), (807, 370), (811, 356)]
# The left_eyebrow in this face has the following points: [(713, 343), (723, 339), (734, 340), (745, 343), (754, 348)]
# The right_eyebrow in this face has the following points: [(770, 350), (780, 348), (789, 348), (798, 350), (805, 355)]
# The nose_bridge in this face has the following points: [(761, 357), (760, 369), (759, 380), (759, 392)]
# The nose_tip in this face has the following points: [(744, 391), (750, 394), (756, 397), (761, 396), (766, 394)]
# The left_eye in this face has the following points: [(725, 353), (732, 351), (739, 352), (744, 356), (738, 357), (731, 356)]
# The right_eye in this face has the following points: [(772, 360), (779, 356), (786, 357), (791, 360), (786, 363), (779, 362)]
# The top_lip in this face has the following points: [(727, 401), (738, 403), (746, 404), (752, 406), (758, 405), (765, 407), (772, 409), (768, 409), (758, 409), (752, 409), (746, 407), (731, 403)]
# The bottom_lip in this face has the following points: [(772, 409), (763, 415), (756, 417), (750, 417), (743, 416), (735, 411), (727, 401), (731, 403), (745, 408), (751, 410), (757, 409), (768, 409)]
# The chin in this face has the following points: [(591, 398), (592, 410), (596, 421), (601, 432), (609, 442), (618, 451), (628, 460), (638, 469), (650, 471), (662, 468), (672, 458), (680, 446), (688, 433), (691, 418), (691, 403), (691, 388), (689, 373)]
# The left_eyebrow in this face has the following points: [(590, 388), (594, 382), (600, 381), (607, 381), (614, 383)]
# The right_eyebrow in this face has the following points: [(634, 378), (642, 373), (651, 370), (662, 369), (671, 371)]
# The nose_bridge in this face has the following points: [(626, 390), (628, 401), (629, 412), (630, 422)]
# The nose_tip in this face has the following points: [(623, 425), (628, 428), (634, 429), (640, 425), (645, 422)]
# The left_eye in this face has the following points: [(600, 395), (605, 391), (611, 390), (618, 394), (612, 396), (605, 397)]
# The right_eye in this face has the following points: [(644, 389), (649, 383), (656, 381), (663, 383), (658, 386), (651, 388)]
# The top_lip in this face has the following points: [(619, 434), (625, 433), (631, 433), (637, 433), (644, 431), (655, 429), (668, 427), (665, 428), (645, 434), (638, 436), (632, 436), (622, 436)]
# The bottom_lip in this face has the following points: [(668, 427), (659, 440), (649, 448), (642, 449), (635, 449), (628, 446), (619, 434), (622, 436), (634, 442), (640, 443), (647, 441), (665, 428)]
# The chin in this face has the following points: [(269, 193), (267, 208), (266, 224), (266, 240), (269, 255), (277, 269), (288, 281), (299, 291), (312, 295), (325, 295), (337, 288), (348, 279), (357, 269), (363, 257), (368, 244), (373, 232), (377, 218)]
# The left_eyebrow in this face has the following points: [(288, 192), (300, 190), (310, 193), (320, 197), (328, 203)]
# The right_eyebrow in this face has the following points: [(344, 207), (354, 205), (363, 206), (370, 208), (375, 214)]
# The nose_bridge in this face has the following points: [(334, 213), (332, 223), (331, 234), (329, 245)]
# The nose_tip in this face has the following points: [(314, 243), (319, 247), (325, 251), (331, 250), (337, 248)]
# The left_eye in this face has the following points: [(300, 203), (306, 202), (313, 204), (318, 209), (311, 208), (304, 206)]
# The right_eye in this face has the following points: [(345, 216), (351, 214), (358, 216), (362, 219), (357, 220), (351, 219)]
# The top_lip in this face has the following points: [(298, 252), (308, 253), (317, 255), (322, 257), (328, 257), (334, 259), (340, 262), (337, 262), (327, 261), (321, 260), (316, 258), (301, 253)]
# The bottom_lip in this face has the following points: [(340, 262), (332, 266), (325, 267), (319, 266), (313, 264), (305, 260), (298, 252), (301, 253), (315, 258), (320, 261), (326, 261), (337, 262)]
# The chin in this face has the following points: [(538, 146), (539, 159), (541, 172), (544, 186), (551, 198), (559, 210), (567, 222), (576, 231), (589, 233), (603, 230), (616, 222), (627, 211), (636, 198), (641, 183), (641, 168), (639, 152), (638, 136)]
# The left_eyebrow in this face has the following points: [(539, 134), (541, 128), (547, 125), (554, 125), (562, 127)]
# The right_eyebrow in this face has the following points: [(578, 126), (588, 123), (599, 122), (609, 124), (617, 130)]
# The nose_bridge in this face has the following points: [(572, 139), (572, 150), (572, 161), (572, 173)]
# The nose_tip in this face has the following points: [(565, 177), (570, 179), (576, 181), (581, 178), (587, 175)]
# The left_eye in this face has the following points: [(548, 143), (552, 139), (558, 138), (563, 141), (558, 143), (553, 143)]
# The right_eye in this face has the following points: [(589, 139), (594, 135), (601, 135), (606, 138), (601, 140), (595, 140)]
# The top_lip in this face has the following points: [(563, 191), (567, 191), (573, 191), (579, 192), (586, 190), (597, 189), (609, 187), (606, 188), (587, 192), (580, 193), (574, 193), (565, 193)]
# The bottom_lip in this face has the following points: [(609, 187), (599, 198), (590, 203), (582, 205), (576, 204), (569, 201), (563, 191), (565, 193), (575, 198), (581, 199), (588, 198), (606, 188)]

# %% [markdown]
# References:
#
# 1.Linkedin Learning-Deep Learning: Face Recognition
