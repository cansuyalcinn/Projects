# %% [markdown]
# # This notebook is used to run the funEstimate function from MEGSA to compute pvalues

# %%
import numpy as np
import scipy.stats as sp
import pandas as pd
import os

import rpy2
from rpy2 import robjects as r
from rpy2.robjects import pandas2ri

# %%
pwd
# Out:
# 'E:\\pancancer_stages_epistasis\\version yiii - MEGSA\\version beta'

# %% [markdown]
# ### Cancer Types: ['BLCA', 'BRCA', 'COADREAD', 'LUAD', 'LUSC', 'SKCM', 'STAD', 'UCEC']
# ### Threshold parameters: 5,10,20

# %%
cancer_type = 'BRCA'
threshold = 20
# infile = 'mutationMat_LAML.txt' #for test
infile = '../data/binary_matrices_all_genes_ep_mutation_filtered/{}_TML_binary_sm.txt'.format(cancer_type)
outpath = '../out/megsa_mutation_filtered_ep_data/'
outfile = outpath + '{}_megsa_result_mutations_all_genes_normal_{}.txt'.format(cancer_type,threshold)
outfile_intact = outpath + '{}_pairs_normal_intact_filtered_subset{}.txt'.format(cancer_type,threshold)

if not os.path.exists(outpath):
    os.makedirs(outpath)

# %%
## Load df, drop column named y (placeholder for TML value)

df = pd.read_csv(infile, sep='\t', header=0,index_col=0)
df.drop('y',1, inplace=True)
df.head()
# Out:
#                   A1BG  A1CF  A2M  A2ML1  A4GALT  A4GNT  AAAS  AACS  AADAC  \
# patients
# TCGA-3C-AAAU-01A     0     0    0      0       0      0     0     0      0
# TCGA-3C-AALI-01A     0     0    1      0       0      0     0     0      0
# TCGA-3C-AALJ-01A     0     0    0      0       0      0     0     0      0
# TCGA-3C-AALK-01A     0     0    0      0       0      0     0     0      0
# TCGA-4H-AAAK-01A     0     0    0      0       0      0     0     0      0
#
#                   AADACL2  ...  ZWILCH  ZWINT  ZXDA  ZXDB  ZXDC  ZYG11A  \
# patients                   ...
# TCGA-3C-AAAU-01A        0  ...       0      0     0     0     0       0
# TCGA-3C-AALI-01A        0  ...       0      0     0     0     1       0
# TCGA-3C-AALJ-01A        0  ...       0      0     0     0     0       0
# TCGA-3C-AALK-01A        0  ...       0      0     0     0     0       0
# TCGA-4H-AAAK-01A        0  ...       0      0     0     0     0       0
#
#                   ZYG11B  ZYX  ZZEF1  ZZZ3
# patients
# TCGA-3C-AAAU-01A       0    0      0     0
# TCGA-3C-AALI-01A       0    0      0     0
# TCGA-3C-AALJ-01A       0    0      0     0
# TCGA-3C-AALK-01A       0    0      0     0
# TCGA-4H-AAAK-01A       0    0      0     0
#
# [5 rows x 16686 columns]

# %% [markdown]
# ## Filter dataframe based on threshold Values

# %%
col_list = []
for col in df.columns:
#     print(col, sum(df[col]))
    if sum(df[col])>threshold:
        col_list.append(col)

df2 = df[col_list]
df2
# Out:
#                   ABCA13  ABCA8  ADAMTSL3  AFF2  AHCTF1  AHNAK  AHNAK2  AK9  \
# patients
# TCGA-3C-AAAU-01A       0      0         0     0       0      0       0    0
# TCGA-3C-AALI-01A       0      1         0     0       1      1       0    0
# TCGA-3C-AALJ-01A       0      0         0     0       0      0       0    0
# TCGA-3C-AALK-01A       0      0         0     0       0      0       0    0
# TCGA-4H-AAAK-01A       0      0         0     0       0      0       0    0
# ...                  ...    ...       ...   ...     ...    ...     ...  ...
# TCGA-WT-AB44-01A       0      0         0     0       0      0       0    0
# TCGA-XX-A899-01A       0      0         0     0       0      0       0    0
# TCGA-XX-A89A-01A       0      0         0     0       0      0       0    0
# TCGA-Z7-A8R5-01A       0      0         0     0       0      0       0    0
# TCGA-Z7-A8R6-01A       0      0         0     0       0      0       0    0
#
#                   AKAP9  AKT1  ...  VPS13D  WDFY3  WDFY4  WDR44  WNK3  XIRP2  \
# patients                       ...
# TCGA-3C-AAAU-01A      0     0  ...       0      0      0      0     0      0
# TCGA-3C-AALI-01A      0     0  ...       0      0      0      0     0      0
# TCGA-3C-AALJ-01A      0     0  ...       0      0      0      0     0      0
# TCGA-3C-AALK-01A      0     0  ...       0      0      0      0     0      0
# TCGA-4H-AAAK-01A      0     0  ...       0      0      0      0     0      0
# ...                 ...   ...  ...     ...    ...    ...    ...   ...    ...
# TCGA-WT-AB44-01A      0     1  ...       0      0      0      0     0      0
# TCGA-XX-A899-01A      0     0  ...       0      0      0      0     0      0
# TCGA-XX-A89A-01A      0     0  ...       0      0      0      0     0      0
# TCGA-Z7-A8R5-01A      0     0  ...       0      0      1      0     0      0
# TCGA-Z7-A8R6-01A      0     0  ...       0      0      0      0     0      0
#
#                   ZAN  ZFHX3  ZFHX4  ZNF292
# patients
# TCGA-3C-AAAU-01A    0      0      0       0
# TCGA-3C-AALI-01A    0      0      1       0
# TCGA-3C-AALJ-01A    0      0      1       0
# TCGA-3C-AALK-01A    0      0      0       0
# TCGA-4H-AAAK-01A    0      0      0       0
# ...               ...    ...    ...     ...
# TCGA-WT-AB44-01A    0      0      0       0
# TCGA-XX-A899-01A    0      0      0       0
# TCGA-XX-A89A-01A    1      0      0       0
# TCGA-Z7-A8R5-01A    0      0      0       0
# TCGA-Z7-A8R6-01A    0      0      0       0
#
# [1026 rows x 238 columns]

# %% [markdown]
# ## Run R script

# %%
## convert python pd dataframe to r dataframe  
pandas2ri.activate()
rdf_in = pandas2ri.py2ri(df2)
rdf_in
# Out:
# R object with classes: ('data.frame',) mapped to:
# <DataFrame - Python:0x000001563959E7C8 / R:0x000001563C4A7960>
# [IntVector, IntVector, IntVector, IntVector, ..., IntVector, IntVector, IntVector, IntVector]
#   ABCA13: <class 'rpy2.robjects.vectors.IntVector'>
#   R object with classes: ('integer',) mapped to:
# <IntVector - Python:0x000001563959E408 / R:0x00000156398E9508>
# [0, 0, 0, 0, ..., 0, 0, 0, 0]
#   ABCA8: <class 'rpy2.robjects.vectors.IntVector'>
#   R object with classes: ('integer',) mapped to:
# <IntVector - Python:0x00000156395967C8 / R:0x00000156398F7A00>
# [0, 1, 0, 0, ..., 0, 0, 0, 0]
#   ADAMTSL3: <class 'rpy2.robjects.vectors.IntVector'>
#   R object with classes: ('integer',) mapped to:
# <IntVector - Python:0x00000156395A2C48 / R:0x0000015639901348>
# [0, 0, 0, 0, ..., 0, 0, 0, 0]
#   AFF2: <class 'rpy2.robjects.vectors.IntVector'>
#   R object with classes: ('integer',) mapped to:
# <IntVector - Python:0x00000156395A2D88 / R:0x000001563990EAC0>
# [0, 0, 0, 0, ..., 0, 0, 0, 0]
# ...
#   AHNAK: <class 'rpy2.robjects.vectors.IntVector'>
#   R object with classes: ('integer',) mapped to:
# <IntVector - Python:0x00000156395A2E88 / R:0x000001563A49C4F8>
# [0, 0, 0, 0, ..., 0, 1, 0, 0]
#   AHNAK2: <class 'rpy2.robjects.vectors.IntVector'>
#   R object with classes: ('integer',) mapped to:
# <IntVector - Python:0x00000156395A2F88 / R:0x000001563A4A3F20>
# [0, 0, 0, 0, ..., 0, 0, 0, 0]
#   AK9: <class 'rpy2.robjects.vectors.IntVector'>
#   R object with classes: ('integer',) mapped to:
# <IntVector - Python:0x00000156395A30C8 / R:0x000001563C452BE8>
# [0, 1, 1, 0, ..., 0, 0, 0, 0]
#   AKAP9: <class 'rpy2.robjects.vectors.IntVector'>
#   R object with classes: ('integer',) mapped to:
# <IntVector - Python:0x00000156395A31C8 / R:0x000001563C45F320>
# [0, 0, 0, 0, ..., 0, 0, 0, 0]

# %%
# run R sctipt from this notebook. Make sure to have the correct R filename
r.r.source('run_megsa.R')
rdf = r.r['run_megsa'](rdf_in, detail=False)
rdf
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-a007378a0b29> in <module>
#       1 # run R sctipt from this notebook. Make sure to have the correct R filename
#       2 r.r.source('run_megsa.R')
# ----> 3 rdf = r.r['run_megsa'](rdf_in, detail=False)
#       4 rdf
#
# ~\.conda\envs\discover\lib\site-packages\rpy2\robjects\functions.py in __call__(self, *args, **kwargs)
#     176                 v = kwargs.pop(k)
#     177                 kwargs[r_k] = v
# --> 178         return super(SignatureTranslatedFunction, self).__call__(*args, **kwargs)
#     179
#     180 pattern_link = re.compile(r'\\link\{(.+?)\}')
#
# ~\.conda\envs\discover\lib\site-packages\rpy2\robjects\functions.py in __call__(self, *args, **kwargs)
#     105             new_kwargs[k] = conversion.py2ri(v)
#     106         res = super(Function, self).__call__(*new_args, **new_kwargs)
# --> 107         res = conversion.ri2ro(res)
#     108         return res
#     109
#
# KeyboardInterrupt:

# %%
# convert R df to pd df
df_temp = r.conversion.ri2py(rdf)
df_temp['gene1'] = df_temp['gene1'].str.upper()
df_temp['gene2'] = df_temp['gene2'].str.upper()
df_temp

# %%
## Write to file
df_temp.to_csv(outfile, sep='\t')

# %% [markdown]
# ## Intact filtering
# The mutual exclusivity values are filtered on Intact PPI

# %%
intact_edge_file = '../data/intact_nodupl_edge_file.txt'
intact_index_file = '../data/intact_nodupl_index_file.txt'

with open(intact_index_file, 'r') as f:
    indices = {line.split()[0]:line.split()[1] for line in f.readlines()}

with open(intact_edge_file, 'r') as f:
    edges = [(indices[line.split()[0]].upper(),indices[line.split()[1]].upper()) for line in f.readlines()]
len(edges)

intact_genes_list = list(indices.values())
intact_genes_list[:5]

# %%
cols = df_temp.columns.to_list()

g1_list = df_temp['gene1'].tolist()
g2_list = df_temp['gene2'].tolist()
llk = df_temp['loglikelyhood'].tolist()
pval = df_temp['pvalue'].tolist()

##CCreate dictionary for lookup
dict_temp = {g1+'\t'+g2:(p,q) for g1,g2,p,q in zip(g1_list,g2_list,llk,pval)}

print('dict_temp_done')

list_temp = []
#edges should have no duplicates
for e in edges:
    g1 = e[0]
    g2 = e[1]
    
    if '{}\t{}'.format(g1,g2) in dict_temp:
        llk,pval = dict_temp['{}\t{}'.format(g1,g2)]
        list_temp.append([g1,g2,llk,pval])
        
    elif '{}\t{}'.format(g2,g1) in dict_temp:
        llk,pval = dict_temp['{}\t{}'.format(g2,g1)]
        list_temp.append([g1,g2,llk,pval])
         
print(len(list_temp))
df_intact = pd.DataFrame(list_temp,columns=cols)
df_intact

# %%
df_intact.to_csv(outfile_intact, sep='\t')
