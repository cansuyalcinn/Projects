# %%
#!pip install dlib
# !pip install face_recognition
#!pip install pillow
import numpy as np # linear algebra
import pandas as pd # data processing
import matplotlib.pyplot as plt
import PIL.Image
import PIL.ImageDraw
import face_recognition
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# Collecting face_recognition
#   Downloading face_recognition-1.3.0-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: Click>=6.0 in /opt/conda/lib/python3.7/site-packages (from face_recognition) (7.1.1)
# Collecting face-recognition-models>=0.3.0
#   Downloading face_recognition_models-0.3.0.tar.gz (100.1 MB)
#      |████████████████████████████████| 100.1 MB 21 kB/s
# Requirement already satisfied: Pillow in /opt/conda/lib/python3.7/site-packages (from face_recognition) (5.4.1)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.7/site-packages (from face_recognition) (1.18.1)
# Requirement already satisfied: dlib>=19.7 in /opt/conda/lib/python3.7/site-packages (from face_recognition) (19.20.0)
# Building wheels for collected packages: face-recognition-models
# done
#   Created wheel for face-recognition-models: filename=face_recognition_models-0.3.0-py2.py3-none-any.whl size=100566172 sha256=ceac5aa9dec40d3727846372019f2877ab2bde8b7a15ece2b43bf72b79b4a0c1
#   Stored in directory: /root/.cache/pip/wheels/d6/81/3c/884bcd5e1c120ff548d57c2ecc9ebf3281c9a6f7c0e7e7947a
# Successfully built face-recognition-models
# Installing collected packages: face-recognition-models, face-recognition
# Successfully installed face-recognition-1.3.0 face-recognition-models-0.3.0
# /kaggle/input/input-people2/ariana.jpg
# /kaggle/input/input-people2/rihanna.jpg
# /kaggle/input/input-people2/input_people/miranda1.jpg
# /kaggle/input/input-people2/input_people/adriana.jpg
# /kaggle/input/input-people/jennifer-aniston-as-rachel.jpg
# /kaggle/input/input-people/friends.jpg

# %%
#data loading
image=face_recognition.load_image_file("../input/input-people/friends.jpg")
face_locations=face_recognition.face_locations(image)
num_of_faces=len(face_locations)
print("{} face(s) found in this image".format(num_of_faces))

pil_image=PIL.Image.fromarray(image)

print("Pixel locations of faces: ")

#face locations are defined and rectange is drawn
for face_location in face_locations:
    top,left,bottom,right=face_location
    print("A face is located at pixel location at Top: {} Left: {} Bottom: {} Right: {}".format(top,left,bottom,right))
    
    draw=PIL.ImageDraw.Draw(pil_image)
    draw.rectangle([left,top,right,bottom],outline="blue",width=3)
    
pil_image.show()
plt.imshow(pil_image)
plt.show()
# Out:
# 6 face(s) found in this image
# Pixel locations of faces:
# A face is located at pixel location at Top: 32 Left: 521 Bottom: 140 Right: 414
# A face is located at pixel location at Top: 307 Left: 223 Bottom: 414 Right: 115
# A face is located at pixel location at Top: 331 Left: 808 Bottom: 438 Right: 700
# A face is located at pixel location at Top: 355 Left: 689 Bottom: 462 Right: 581
# A face is located at pixel location at Top: 175 Left: 378 Bottom: 283 Right: 270
# A face is located at pixel location at Top: 96 Left: 640 Bottom: 225 Right: 511

# %% [markdown]
# References:
#
# 1.Linkedin Learning-Deep Learning: Face Recognition
