# %%
from tensorflow.python.client import device_lib
device_lib.list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 4907087466330060470, name: "/device:XLA_CPU:0"
#  device_type: "XLA_CPU"
#  memory_limit: 17179869184
#  locality {
#  }
#  incarnation: 18383637229664472366
#  physical_device_desc: "device: XLA_CPU device", name: "/device:XLA_GPU:0"
#  device_type: "XLA_GPU"
#  memory_limit: 17179869184
#  locality {
#  }
#  incarnation: 9665640180301099101
#  physical_device_desc: "device: XLA_GPU device", name: "/device:GPU:0"
#  device_type: "GPU"
#  memory_limit: 14640891840
#  locality {
#    bus_id: 1
#    links {
#    }
#  }
#  incarnation: 11354930248293479194
#  physical_device_desc: "device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5"]

# %%
# !git clone https://github.com/tensorflow/models.git
# Out:
# Cloning into 'models'...
# remote: Enumerating objects: 43014, done.
# remote: Total 43014 (delta 0), reused 0 (delta 0), pack-reused 43014
# Receiving objects: 100% (43014/43014), 549.83 MiB | 37.51 MiB/s, done.
# Resolving deltas: 100% (29277/29277), done.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import os
os.environ['PYTHONPATH'] += ':/content/models/research/slim/'
os.environ['PYTHONPATH'] += ':/content/models/research/:/content/models/research/object_detection/'
os.environ['PYTHONPATH'] += ':/content/models'

# %%
work_dir = "/content/models/research/deeplab/"
dataset_dir = "datasets/"

custom_dataset_dir = "custom/"

os.mkdir(work_dir +dataset_dir + custom_dataset_dir)

exp_dir= work_dir + dataset_dir + custom_dataset_dir + "exp"

os.mkdir(exp_dir)

os.mkdir(os.path.join(exp_dir,"train_on_trainval_set"))

init_dir = work_dir +dataset_dir + custom_dataset_dir +"exp/train_on_trainval_set/init_models"

os.mkdir(init_dir)

# %%
#!wget http://download.tensorflow.org/models/deeplabv3_pascal_train_aug_2018_01_04.tar.gz -P /content/models/research/deeplab/datasets/custom/exp/train_on_trainval_set/init_models


# xception_65_imagenet !wget http://download.tensorflow.org/models/deeplabv3_xception_2018_01_04.tar.gz -P /content/models/research/deeplab/datasets/custom/exp/train_on_trainval_set/init_models

# xception_41_imagenet !wget http://download.tensorflow.org/models/xception_41_2018_05_09.tar.gz -P /content/models/research/deeplab/datasets/custom/exp/train_on_trainval_set/init_models

# xception_71_imagenet !wget http://download.tensorflow.org/models/xception_71_2018_05_09.tar.gz -P /content/models/research/deeplab/datasets/custom/exp/train_on_trainval_set/init_models

#!wget http://download.tensorflow.org/models/resnet_v1_101_2018_05_04.tar.gz -P /content/models/research/deeplab/datasets/custom/exp/train_on_trainval_set/init_models
#!wget http://download.tensorflow.org/models/xception_71_2018_05_09.tar.gz -P /content/models/research/deeplab/datasets/custom/exp/train_on_trainval_set/init_models

#!wget http://download.tensorflow.org/models/deeplabv3_xception_2018_01_04.tar.gz -P /content/models/research/deeplab/datasets/custom/exp/train_on_trainval_set/init_models
# !wget http://download.tensorflow.org/models/deeplabv3_pascal_trainval_2018_01_04.tar.gz -P /content/models/research/deeplab/datasets/custom/exp/train_on_trainval_set/init_models

# here you should import your model. Transfer learning. Just put its link.
# Out:
# --2020-09-01 12:14:36--  http://download.tensorflow.org/models/deeplabv3_pascal_trainval_2018_01_04.tar.gz
# Resolving download.tensorflow.org (download.tensorflow.org)... 108.177.98.128, 2607:f8b0:400e:c06::80
# Connecting to download.tensorflow.org (download.tensorflow.org)|108.177.98.128|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 460669898 (439M) [application/x-tar]
# Saving to: ‘/content/models/research/deeplab/datasets/custom/exp/train_on_trainval_set/init_models/deeplabv3_pascal_trainval_2018_01_04.tar.gz’
#
# deeplabv3_pascal_tr 100%[===================>] 439.33M   120MB/s    in 3.7s
#
# 2020-09-01 12:14:40 (120 MB/s) - ‘/content/models/research/deeplab/datasets/custom/exp/train_on_trainval_set/init_models/deeplabv3_pascal_trainval_2018_01_04.tar.gz’ saved [460669898/460669898]

# %%
# %cd /content/models/research/deeplab/datasets/custom/exp/train_on_trainval_set/init_models
# Out:
# /content/models/research/deeplab/datasets/custom/exp/train_on_trainval_set/init_models

# %%
#!tar -xf /content/models/research/deeplab/datasets/custom/exp/train_on_trainval_set/init_models/deeplabv3_pascal_train_aug_2018_01_04.tar.gz

# !tar -xf /content/models/research/deeplab/datasets/custom/exp/train_on_trainval_set/init_models/deeplabv3_pascal_trainval_2018_01_04.tar.gz

# %%
# %cd /content/models/research/deeplab/datasets/custom/
# Out:
# /content/models/research/deeplab/datasets/custom

# %%
# !unrar x "/content/models/research/deeplab/datasets/custom/tfrecord.rar" "/content/models/research/deeplab/datasets/custom/"
#you should have a record file of your images.
# Out:
# UNRAR 5.50 freeware      Copyright (c) 1993-2017 Alexander Roshal
#
#
# Extracting from /content/models/research/deeplab/datasets/custom/tfrecord.rar
#
# Creating    /content/models/research/deeplab/datasets/custom/tfrecord  OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# All OK

# %% [markdown]
# # Training

# %%
# %tensorflow_version 1.15.2
# Out:
# `%tensorflow_version` only switches the major version: 1.x or 2.x.
# You set: `1.15.2`. This will be interpreted as: `1.x`.
#
#
# TensorFlow 1.x selected.

# %%
# %load_ext tensorboard
# %tensorboard --logdir "/content/drive/My Drive/log"

# %%
# %cd /content/models/research
# Out:
# /content/models/research

# %%
# !pip install tf_slim
# Out:
# ...
#      |████████████████████████████████| 358kB 4.9MB/s
# ...

# %% [markdown]
#  Upload sh files and change before run

# %%
# !sh train-pqr.sh

# %%
# !sh eval-pqr.sh

# %%
# %load_ext tensorboard
tensorboard --logdir /content/models/research/deeplab/datasets/custom/exp/train_on_trainval_set/train

#TRAIN_LOG_DIR

# %%
# !sh vis-pqr.sh
# Out:
# WARNING:tensorflow:From /content/drive/My Drive/Colab Notebooks/maier/inovako/models-master/research/deeplab/core/conv2d_ws.py:40: The name tf.layers.Layer is deprecated. Please use tf.compat.v1.layers.Layer instead.
#
# WARNING:tensorflow:From /content/models/research/deeplab/vis.py:327: The name tf.app.run is deprecated. Please use tf.compat.v1.app.run instead.
#
# WARNING:tensorflow:From /content/models/research/deeplab/vis.py:195: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
#
# W0811 14:22:39.110890 140176203024256 module_wrapper.py:139] From /content/models/research/deeplab/vis.py:195: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
#
# WARNING:tensorflow:From /content/models/research/deeplab/vis.py:195: The name tf.logging.INFO is deprecated. Please use tf.compat.v1.logging.INFO instead.
#
# ...

# %% [markdown]
# # Export Inference Graph

# %%
# !sh export.sh
# Out:
# WARNING:tensorflow:From /content/models/research/deeplab/core/conv2d_ws.py:40: The name tf.layers.Layer is deprecated. Please use tf.compat.v1.layers.Layer instead.
#
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From /content/models/research/deeplab/export_model.py:201: The name tf.app.run is deprecated. Please use tf.compat.v1.app.run instead.
#
# WARNING:tensorflow:From /content/models/research/deeplab/export_model.py:117: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
#
# ...

# %% [markdown]
# # Make Prediction

# %%
import cv2
import tensorflow as tf
import numpy as np
from PIL import Image

from skimage.transform import resize

class DeepLabModel():
    """Class to load deeplab model and run inference."""

    INPUT_TENSOR_NAME = 'ImageTensor:0'
    OUTPUT_TENSOR_NAME = 'SemanticPredictions:0'
    INPUT_SIZE = 1300


    def __init__(self, path):
        """Creates and loads pretrained deeplab model."""
        self.graph = tf.Graph()

        graph_def = None
        # Extract frozen graph from tar archive.

        with tf.gfile.GFile(path, 'rb')as file_handle:
            graph_def = tf.GraphDef.FromString(file_handle.read())

        if graph_def is None:
            raise RuntimeError('Cannot find inference graph')

        with self.graph.as_default():
            tf.import_graph_def(graph_def, name='')

        self.sess = tf.Session(graph=self.graph)


    def run(self, image):
        """Runs inference on a single image.

        Args:
          image: A PIL.Image object, raw input image.

        Returns:
          seg_map: np.array. values of pixels are classes
        """

        width, height = image.size

        resize_ratio = 1.0 * self.INPUT_SIZE / max(width, height)
        target_size = (int(resize_ratio * width), int(resize_ratio * height))

        resized_image = image.convert('RGB').resize(target_size, Image.ANTIALIAS)

        batch_seg_map = self.sess.run(
           self.OUTPUT_TENSOR_NAME,
           feed_dict={self.INPUT_TENSOR_NAME: [np.asarray(resized_image)]})

        seg_map = batch_seg_map[0]        

        seg_map = resize(seg_map.astype(np.uint8), (height, width), preserve_range=True, order=0, anti_aliasing=False)

        return seg_map

# %%
FROZEN_GRAPH_PATH ="/content/models/research/deeplab/datasets/custom/exp/train_on_trainval_set/export/frozen_inference_graph.pb"

# %%
IMAGE_PATH = "/content/models/research/280730_8.jpg"
model = DeepLabModel(FROZEN_GRAPH_PATH)
img = Image.open(IMAGE_PATH)
seg_map = model.run(img)

# %%
img_arr = np.array(img)
colors = [(150, 120, 90), (119, 11, 32), (0,0,142)] 
for c in range(0, 3):
    img_arr[seg_map == c] = 0.5 * img_arr[seg_map == c] + 0.5 * np.array(colors[c])
Image.fromarray(img_arr)
# Out:
# <PIL.Image.Image image mode=RGB size=1000x1300 at 0x7FD84D439630>

# %%
#cv2.imwrite('/content/test3.png',img_arr)
image = Image.fromarray(img_arr)
image.save("/content/test_280730_8.jpg")

# %%
seg_map
# Out:
# array([[2., 2., 2., ..., 2., 2., 2.],
#        [2., 2., 2., ..., 2., 2., 2.],
#        [2., 2., 2., ..., 2., 2., 2.],
#        ...,
#        [2., 2., 2., ..., 2., 2., 2.],
#        [2., 2., 2., ..., 2., 2., 2.],
#        [2., 2., 2., ..., 2., 2., 2.]])
